# %%
import os
import json
from dotenv import load_dotenv
from vertexai.generative_models import GenerativeModel
from gtts import gTTS
import vertexai

# Load environment variables
load_dotenv()
GOOGLE_APPLICATION_CREDENTIALS = os.getenv("GOOGLE_APPLICATION_CREDENTIALS")
PROJECT_ID = os.getenv("GCP_PROJECT_ID")
LOCATION = os.getenv("GCP_REGION")

# Initialize Vertex AI
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = GOOGLE_APPLICATION_CREDENTIALS
vertexai.init(project=PROJECT_ID, location=LOCATION)

# Load JSON file
def load_json(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        return json.load(file)

# Generate cohesive Podcast Script using Gemini
def generate_combined_script(summaries):
    # Combine summaries into a single input for Gemini
    combined_input = "\n\n".join([f"Article {i+1}: {summary}" for i, summary in enumerate(summaries)])

    # Prompt for Gemini
    prompt = f"""
    You're a podcast script writer tasked with creating a technical, yet amusing and catchy podcast episode.
    Use the following summaries of articles to write a single cohesive podcast script. Make it engaging, informative, 
    and flow naturally like a story while retaining the technical details:
    
    {combined_input}

    Start with a hook, include fun facts or light humor where appropriate, and conclude with a strong ending.
    """
    # Generate content using Gemini
    model = GenerativeModel("gemini-1.0-pro")  # Use the latest Gemini model
    response = model.generate_content(prompt)
    return response.text if response else "Failed to generate script."

# Convert Script to Speech
def text_to_speech(script, output_file):
    tts = gTTS(script, lang="en")
    tts.save(output_file)
    print(f"Audio saved as: {output_file}")

# Main Function
if __name__ == "__main__":
    # Load JSON file
    json_file_path = "output_data.json"  # Replace with your file path
    data = load_json(json_file_path)

    # Extract summaries from JSON
    summaries = []
    for article in data:
        summary = article.get("summary")
        if summary:
            summaries.append(summary)
    
    # Generate podcast script
    print("Generating cohesive podcast script...")
    podcast_script = generate_combined_script(summaries)
    print("Generated Script:\n", podcast_script)
    
    # Convert the script to audio
    print("Converting script to audio...")
    output_audio = "podcast_output.mp3"
    text_to_speech(podcast_script, output_audio)
    print("Process completed successfully!")
# Out:
# Generating cohesive podcast script...
# Generated Script:
#  ## Episode Title: Tech Takeoff: Gaming, Fintech, and Spacefaring Startups
#
# **Intro**
#
# (Upbeat music fades in)
#
# **Host:** Hey everyone, welcome to Tech Takeoff! Today, we're diving deep into the world of exciting startups, bold investors, and cosmic ambitions. Buckle up, it's gonna be a wild ride!
#
# **Gaming on the Rise**
#
# **Host:** First stop, the mobile gaming scene. Turkish company Agave Games just raked in a whopping $18 million in Series A funding. Why? Their hit game, Find the Cat, went viral, racking up over 10 million downloads and $10 million in revenue in its first quarter. Talk about finding success!
#
# **Fun Fact:** Did you know Find the Cat uses AI to generate its intricate illustrations? These clever algorithms are hiding those sneaky felines, adding a whole new layer of fun to the game.
#
# **Host:** Agave isn't stopping there. They're planning to use the fresh funds to expand their team and develop even more innovative games, all powered by AI to make them purrfectly engaging. Get it? Purrfectly? Okay, maybe I'll leave the jokes to the cats.
#
# **Fintech's Big Comeback**
#
# **Host:** Moving on from playful kittens to serious finances, fintech company Tyme Group just landed a massive $250 million investment, led by Nubank. This skyrockets Tyme's valuation to a cool $1.5 billion, marking a major comeback for investor interest in the fintech scene.
#
# **Host:** So, what's Tyme's plan with this hefty cash injection? They're eyeing expansion into Vietnam and Indonesia, with their sights set on a New York IPO by 2028. That's some serious ambition, folks!
#
# **Nubank's Strategic Play**
#
# **Host:** Nubank isn't just throwing money around for fun. They're strategically investing in Tyme to diversify their portfolio and tap into the booming emerging market growth. It's a win-win situation for both companies.
#
# **Hexa's Startup Factory**
#
# **Host:** Now, let's switch gears and visit the world of innovative startups. B2B software startup studio Hexa has been busy launching exciting new ventures across various sectors.
#
# **From AI-powered customer support to tech-assisted weight loss programs, Hexa is pushing boundaries and creating solutions for real-world problems. We'll keep an eye on how these promising startups unfold.**
#
# **Space Exploration: The Final Frontier**
#
# **Host:** As we reach the final frontier, we have some exciting news from the space industry. TechCrunch Space newsletters are coming to an end, but 2024 promises a year packed with cosmic events.
#
# **Host:** SpaceX is gearing up for more launches, Blue Origin is preparing its first New Glenn launch, and startups like Impulse Space and Varda are ready to take on ambitious missions. It's a thrilling time to be a space enthusiast!
#
# **Threads: Meta's Social Media Gambit**
#
# **Host:** Back on Earth, Meta's new platform Threads is making waves. With over 100 million daily active users and 300 million monthly active users, Threads is growing rapidly, fueled by an exodus of users from a rival platform.
#
# **Host:** Meta is aggressively promoting Threads, adding new features and constantly highlighting its impressive growth. With consistent user sign-ups reaching a million per day, Threads is definitely a force to be reckoned with in the social media landscape.
#
# **Outro**
#
# **Host:** From AI-powered cats to cosmic ambitions, this episode has covered a lot of ground. It's clear that the tech world is constantly evolving, filled with exciting innovations and bold ventures. We'll be here to keep you updated on everything that's taking off in the tech world. Until next time, stay curious and keep exploring!
#
# (Music fades out)
#
# Converting script to audio...
# Audio saved as: podcast_output.mp3
# Process completed successfully!

# %%
import os
import json
import re
from dotenv import load_dotenv
from vertexai.generative_models import GenerativeModel
from gtts import gTTS
import vertexai
from google.cloud import texttospeech

# Load environment variables
load_dotenv()
GOOGLE_APPLICATION_CREDENTIALS = os.getenv("GOOGLE_APPLICATION_CREDENTIALS")
PROJECT_ID = os.getenv("GCP_PROJECT_ID")
LOCATION = os.getenv("GCP_REGION")

# Initialize Vertex AI
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = GOOGLE_APPLICATION_CREDENTIALS
vertexai.init(project=PROJECT_ID, location=LOCATION)

# Load JSON file
def load_json(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        return json.load(file)

# Clean Podcast Script
def clean_text(text):
    """
    Cleans the podcast script to make it suitable for text-to-speech.
    Removes markdown symbols, labels, and special cues.
    """
    # Step 1: Remove Markdown headers (##, **, etc.)
    text = re.sub(r'[#*]+', '', text)  # Remove # and * symbols
    text = re.sub(r'\*\*(.*?)\*\*', r'\1', text)  # Remove ** around words
    
    # Step 2: Remove section labels like "Host:"
    text = re.sub(r'\b(H|h)ost:\s*', '', text)
    
    # Step 3: Remove content in parentheses (e.g., "(Upbeat music fades in)")
    text = re.sub(r'\(.*?\)', '', text)
    
    # Step 4: Remove extra spaces and blank lines
    text = re.sub(r'\n+', '\n', text)  # Remove extra newlines
    text = re.sub(r'\s{2,}', ' ', text)  # Replace multiple spaces with a single space

    # Step 4: Remove music-related parts (e.g., Intro Music, Outro Music Fades)
    text = re.sub(r'(?i)\b(Intro Music|Outro Music|Outro Music Fades)\b', '', text)

    # Step 5: Trim whitespace
    text = text.strip()
    
    return text

# Generate cohesive Podcast Script using Gemini
def generate_combined_script(summaries):
    # Combine summaries into a single input for Gemini
    combined_input = "\n\n".join([f"Article {i+1}: {summary}" for i, summary in enumerate(summaries)])

    # Prompt for Gemini
    prompt = f"""
    You're a podcast script writer tasked with creating a technical, yet amusing and catchy podcast episode.
    Use the following summaries of articles to write a single cohesive podcast script. Make it engaging, informative, 
    and flow naturally like a story while retaining the technical details:
    
    {combined_input}

    Start with a hook, include fun facts or light humor where appropriate, and conclude with a strong ending.
    """
    # Generate content using Gemini
    model = GenerativeModel("gemini-1.0-pro")  # Use the latest Gemini model
    response = model.generate_content(prompt)
    return response.text if response else "Failed to generate script."

# Convert Script to Speech
# def text_to_speech(script, output_file):
#     tts = gTTS(script, lang="en")
#     tts.save(output_file)
#     print(f"Audio saved as: {output_file}")


def text_to_speech(script, output_file):
    """
    Converts text to high-quality speech using Google Cloud Text-to-Speech.
    """
    # Initialize the TTS client
    client = texttospeech.TextToSpeechClient()

    # Prepare the input text
    synthesis_input = texttospeech.SynthesisInput(text=script)

    # Configure the voice
    voice = texttospeech.VoiceSelectionParams(
        language_code="en-US",  # Language
        name="en-US-Wavenet-F",  # Wavenet voice for natural sound
        ssml_gender=texttospeech.SsmlVoiceGender.FEMALE
    )

    # Configure audio settings
    audio_config = texttospeech.AudioConfig(
        audio_encoding=texttospeech.AudioEncoding.MP3,
        speaking_rate=1.0,  # Adjust the speed if necessary
        pitch=0.0  # Adjust the pitch for better tone
    )

    # Generate speech
    response = client.synthesize_speech(
        input=synthesis_input, voice=voice, audio_config=audio_config
    )

    # Save the audio to an output file
    with open(output_file, "wb") as out:
        out.write(response.audio_content)
        print(f"Audio content written to file: {output_file}")


# Main Function
if __name__ == "__main__":
    # Load JSON file
    json_file_path = "output_data.json"  # Replace with your file path
    data = load_json(json_file_path)

    # Extract summaries from JSON
    summaries = []
    for article in data:
        summary = article.get("summary")
        if summary:
            summaries.append(summary)
    
    # Generate podcast script
    print("Generating cohesive podcast script...")
    podcast_script = generate_combined_script(summaries)
    print("Original Script:\n", podcast_script)
    
    # Clean the script
    print("\nCleaning the podcast script...")
    cleaned_script = clean_text(podcast_script)
    print("Cleaned Script:\n", cleaned_script)
    
    # Convert the cleaned script to audio
    print("\nConverting script to audio...")
    output_audio = "podcast_output.mp3"
    text_to_speech(cleaned_script, output_audio)
    print("Process completed successfully!")
# Out:
# Generating cohesive podcast script...
# Original Script:
#  (Sound of upbeat music and a jingle)
#
# **Host:** Welcome back, tech enthusiasts! It's time for another episode of "Tech Talk," where we delve into the fascinating world of technology, trends, and the people shaping it. I'm your host, [Your Name], and today we've got a show packed with exciting news and insights.
#
# **Co-host:** That's right! We've got funding rounds, new startups, space updates, and even social media drama. Buckle up, because this episode is going to be a wild ride!
#
# **Host:** Let's kick things off with a big win for Agave Games, the Turkish company behind the wildly popular mobile game "Find the Cat." They just snagged a whopping $18 million in Series A funding! This feline-finding frenzy has reached over 10 million downloads and generated $10 million in revenue on Android alone. Talk about purr-fect success!
#
# **Co-host:** Now, for all you AI enthusiasts out there, Agave isn't stopping there. They're planning to use this funding to supercharge their games with even more AI-powered features. Their goal? To become a $100 million revenue company. Watch out, world, these cats are coming in hot!
#
# **Host:** Moving on to the world of fintech, Tyme Group has just raised a massive $250 million, led by none other than Nubank. This investment values Tyme at a cool $1.5 billion, marking a significant comeback for the fintech sector. Tyme is setting its sights on expansion into Vietnam and Indonesia, with an IPO in New York on the horizon for 2028.
#
# **Co-host:** It's clear that Nubank is making a strategic move here, diversifying their portfolio and tapping into the potential of emerging markets. With Tyme's innovative approach, this partnership is one to watch.
#
# **Host:** Now, let's shift gears to the world of startups. B2B software startup studio Hexa has unveiled a whole new batch of exciting ventures. From AI-powered customer support to voice-first field sales assistants, Hexa is tackling challenges across various industries. We're particularly excited about their health-focused startups, like Annette for weight loss and DermaScan for skin cancer detection. These could be game-changers!
#
# **Co-host:** And speaking of game-changers, the space industry is gearing up for a busy 2024. SpaceX is expected to make significant progress, while Rocket Lab's Neutron rocket is set to make its debut. We'll also see missions from startups like Impulse Space and Varda, and possibly even the sale of Boeing's space business.
#
# **Host:** But wait, there's more! Blue Origin is finally getting close to launching its New Glenn rocket, pending regulatory approvals. And Fleet Space Technologies just secured $100 million to enable mineral prospecting from space. Talk about out-of-this-world innovation!
#
# **Co-host:** Even the astronauts on the International Space Station are getting in on the festive spirit. They've been celebrating Christmas for 18 years now, complete with decorations and all the trimmings. It's a reminder that even in the vastness of space, the human spirit can find joy and connection.
#
# **Host:** And finally, we have some social media drama to spice things up. Meta's Threads platform has exploded in popularity, boasting over 100 million daily active users. This comes as rival platform X is experiencing an exodus of users. Meta is aggressively promoting Threads, competing head-to-head with Bluesky. It's a battle for social media dominance, folks!
#
# **Co-host:** So there you have it, folks! A whirlwind tour of the latest and greatest in the tech world. From record-breaking funding rounds to innovative startups and space exploration, it's an exciting time to be alive.
#
# **Host:** As always, we'll keep you updated on all the latest developments. Don't forget to subscribe to our podcast and share it with your friends. Until next time, stay curious, stay informed, and keep exploring the amazing world of technology!
#
# (Sound of upbeat music and outro)
#
# Cleaning the podcast script...
# Cleaned Script:
#  Welcome back, tech enthusiasts! It's time for another episode of "Tech Talk," where we delve into the fascinating world of technology, trends, and the people shaping it. I'm your host, [Your Name], and today we've got a show packed with exciting news and insights. Co-That's right! We've got funding rounds, new startups, space updates, and even social media drama. Buckle up, because this episode is going to be a wild ride!
# Let's kick things off with a big win for Agave Games, the Turkish company behind the wildly popular mobile game "Find the Cat." They just snagged a whopping $18 million in Series A funding! This feline-finding frenzy has reached over 10 million downloads and generated $10 million in revenue on Android alone. Talk about purr-fect success!
# Co-Now, for all you AI enthusiasts out there, Agave isn't stopping there. They're planning to use this funding to supercharge their games with even more AI-powered features. Their goal? To become a $100 million revenue company. Watch out, world, these cats are coming in hot!
# Moving on to the world of fintech, Tyme Group has just raised a massive $250 million, led by none other than Nubank. This investment values Tyme at a cool $1.5 billion, marking a significant comeback for the fintech sector. Tyme is setting its sights on expansion into Vietnam and Indonesia, with an IPO in New York on the horizon for 2028. Co-It's clear that Nubank is making a strategic move here, diversifying their portfolio and tapping into the potential of emerging markets. With Tyme's innovative approach, this partnership is one to watch.
# Now, let's shift gears to the world of startups. B2B software startup studio Hexa has unveiled a whole new batch of exciting ventures. From AI-powered customer support to voice-first field sales assistants, Hexa is tackling challenges across various industries. We're particularly excited about their health-focused startups, like Annette for weight loss and DermaScan for skin cancer detection. These could be game-changers!
# Co-And speaking of game-changers, the space industry is gearing up for a busy 2024. SpaceX is expected to make significant progress, while Rocket Lab's Neutron rocket is set to make its debut. We'll also see missions from startups like Impulse Space and Varda, and possibly even the sale of Boeing's space business.
# But wait, there's more! Blue Origin is finally getting close to launching its New Glenn rocket, pending regulatory approvals. And Fleet Space Technologies just secured $100 million to enable mineral prospecting from space. Talk about out-of-this-world innovation!
# Co-Even the astronauts on the International Space Station are getting in on the festive spirit. They've been celebrating Christmas for 18 years now, complete with decorations and all the trimmings. It's a reminder that even in the vastness of space, the human spirit can find joy and connection.
# And finally, we have some social media drama to spice things up. Meta's Threads platform has exploded in popularity, boasting over 100 million daily active users. This comes as rival platform X is experiencing an exodus of users. Meta is aggressively promoting Threads, competing head-to-head with Bluesky. It's a battle for social media dominance, folks!
# Co-So there you have it, folks! A whirlwind tour of the latest and greatest in the tech world. From record-breaking funding rounds to innovative startups and space exploration, it's an exciting time to be alive.
# As always, we'll keep you updated on all the latest developments. Don't forget to subscribe to our podcast and share it with your friends. Until next time, stay curious, stay informed, and keep exploring the amazing world of technology!
#
# Converting script to audio...
# Audio content written to file: podcast_output.mp3
# Process completed successfully!

# %%
from google.cloud import texttospeech

def text_to_speech(script, output_file):
    """
    Converts text to high-quality speech using Google Cloud Text-to-Speech.
    """
    # Initialize the TTS client
    client = texttospeech.TextToSpeechClient()

    # Prepare the input text
    synthesis_input = texttospeech.SynthesisInput(text=script)

    # Configure the voice
    voice = texttospeech.VoiceSelectionParams(
        language_code="en-US",  # Language
        name="en-US-Wavenet-F",  # Wavenet voice for natural sound
        ssml_gender=texttospeech.SsmlVoiceGender.FEMALE
    )

    # Configure audio settings
    audio_config = texttospeech.AudioConfig(
        audio_encoding=texttospeech.AudioEncoding.MP3,
        speaking_rate=1.0,  # Adjust the speed if necessary
        pitch=0.0  # Adjust the pitch for better tone
    )

    # Generate speech
    response = client.synthesize_speech(
        input=synthesis_input, voice=voice, audio_config=audio_config
    )

    # Save the audio to an output file
    with open(output_file, "wb") as out:
        out.write(response.audio_content)
        print(f"Audio content written to file: {output_file}")
